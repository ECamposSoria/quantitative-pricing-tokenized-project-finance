# %% [markdown]
# # AMM Introduction (Placeholder)
#
# Outline the architecture of the `pftoken.amm` package and provide samples for constant-product pools.
#
# Future content:
#
# - Instantiate `ConstantProductPool` and run basic swaps.
# - Visualise price paths via `pftoken.viz.amm_viz`.
# - Compare DCF vs. market pricing using `scripts/compare_dcf_market.py`.
